# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
happy_2015 = pd.read_csv("~/python3/projet/projet_happiness/2015.csv")
happy_2016 = pd.read_csv("~/python3/projet/projet_happiness/2016.csv")
happy_2017 = pd.read_csv("~/python3/projet/projet_happiness/2017.csv")
happy_2018 = pd.read_csv("~/python3/projet/projet_happiness/2018.csv")
happy_2019 = pd.read_csv("~/python3/projet/projet_happiness/2019.csv")

# %%
happy_2015.head(10)
# Out:
#        Country                     Region  Happiness Rank 2015  \
# 0  Switzerland             Western Europe                    1
# 1      Iceland             Western Europe                    2
# 2      Denmark             Western Europe                    3
# 3       Norway             Western Europe                    4
# 4       Canada              North America                    5
# 5      Finland             Western Europe                    6
# 6  Netherlands             Western Europe                    7
# 7       Sweden             Western Europe                    8
# 8  New Zealand  Australia and New Zealand                    9
# 9    Australia  Australia and New Zealand                   10
#
#    Happiness Score 2015  Standard Error 2015  Economy (GDP per Capita) 2015  \
# 0                 7.587              0.03411                        1.39651
# 1                 7.561              0.04884                        1.30232
# ...

# %%
happy_2016.head(10)
# Out:
#        Country                     Region  Happiness Rank 2016  \
# 0      Denmark             Western Europe                    1
# 1  Switzerland             Western Europe                    2
# 2      Iceland             Western Europe                    3
# 3       Norway             Western Europe                    4
# 4      Finland             Western Europe                    5
# 5       Canada              North America                    6
# 6  Netherlands             Western Europe                    7
# 7  New Zealand  Australia and New Zealand                    8
# 8    Australia  Australia and New Zealand                    9
# 9       Sweden             Western Europe                   10
#
#    Happiness Score 2016  Lower Confidence Interval 2016  \
# 0                 7.526                           7.460
# 1                 7.509                           7.428
# 2                 7.501                           7.333
# ...

# %%
happy_2017.head(10)
# Out:
#        Country  Happiness Rank 2017  Happiness Score 2017  Whisker high 2017  \
# 0       Norway                    1                 7.537           7.594445
# 1      Denmark                    2                 7.522           7.581728
# 2      Iceland                    3                 7.504           7.622030
# 3  Switzerland                    4                 7.494           7.561772
# 4      Finland                    5                 7.469           7.527542
# 5  Netherlands                    6                 7.377           7.427426
# 6       Canada                    7                 7.316           7.384403
# 7  New Zealand                    8                 7.314           7.379510
# 8       Sweden                    9                 7.284           7.344095
# 9    Australia                   10                 7.284           7.356651
#
#    Whisker low 2017  Economy GDP per Capita 2017  Family 2017  \
# ...

# %%
happy_2018.head(10)
# Out:
#    Overall rank 2018 Country or region  Score 2018  GDP per capita 2018  \
# 0                  1           Finland       7.632                1.305
# 1                  2            Norway       7.594                1.456
# 2                  3           Denmark       7.555                1.351
# 3                  4           Iceland       7.495                1.343
# 4                  5       Switzerland       7.487                1.420
# 5                  6       Netherlands       7.441                1.361
# 6                  7            Canada       7.328                1.330
# 7                  8       New Zealand       7.324                1.268
# 8                  9            Sweden       7.314                1.355
# 9                 10         Australia       7.272                1.340
#
#    Social support 2018  Healthy life expectancy 2018  \
# 0                1.592                         0.874
# 1                1.582                         0.861
# ...

# %%
happy_2019.head(10)
# Out:
#    Overall rank 2019 Country or region  Score 2019  GDP per capita 2019  \
# 0                  1           Finland       7.769                1.340
# 1                  2           Denmark       7.600                1.383
# 2                  3            Norway       7.554                1.488
# 3                  4           Iceland       7.494                1.380
# 4                  5       Netherlands       7.488                1.396
# 5                  6       Switzerland       7.480                1.452
# 6                  7            Sweden       7.343                1.387
# 7                  8       New Zealand       7.307                1.303
# 8                  9            Canada       7.278                1.365
# 9                 10           Austria       7.246                1.376
#
#    Social support 2019  Healthy life expectancy 2019  \
# 0                1.587                         0.986
# 1                1.573                         0.996
# ...

# %%
plt.rcParams['figure.figsize'] = (20, 15)
sns.heatmap(happy_2015.corr(), cmap = 'copper', annot = True)
# Out:
# <AxesSubplot:>

# %%
happy_2016.head(5)
# Out:
#        Country          Region  Happiness Rank 2016  Happiness Score 2016  \
# 0      Denmark  Western Europe                    1                 7.526
# 1  Switzerland  Western Europe                    2                 7.509
# 2      Iceland  Western Europe                    3                 7.501
# 3       Norway  Western Europe                    4                 7.498
# 4      Finland  Western Europe                    5                 7.413
#
#    Lower Confidence Interval 2016  Upper Confidence Interval 2016  \
# 0                           7.460                           7.592
# 1                           7.428                           7.590
# 2                           7.333                           7.669
# 3                           7.421                           7.575
# 4                           7.351                           7.475
#
#    Economy (GDP per Capita) 2016  Family 2016  Health (Life Expectancy) 2016  \
# ...

# %%
plt.rcParams['figure.figsize'] = (20, 15)
sns.heatmap(happy_2016.corr(), cmap = 'copper', annot = True)
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x="Region", y="Happiness Score 2015", data= happy_2015)
plt.xticks(rotation=45)
plt.show()

# %%
sns.boxplot(x="Region", y="Freedom 2015", data= happy_2015)
plt.xticks(rotation=45)
plt.show()

# %%
sns.relplot(x="Region", y="Freedom 2015", data= happy_2015)
plt.xticks(rotation=45)
plt.show()

# %%
sns.lmplot(y="Happiness Score 2015",x="Freedom 2015",data = happy_2015)
plt.suptitle("Happiness score and Freedom 2015", fontsize=15)
# Out:
# Text(0.5, 0.98, 'Happiness score and Freedom 2015')

# %%
sns.lmplot(y="Happiness Score 2016",x="Freedom 2016",data = happy_2016)
plt.suptitle("Happiness score and Freedom 2016", fontsize=15)
# Out:
# Text(0.5, 0.98, 'Happiness score and Freedom 2016')

# %%
sns.lmplot(y="Happiness Score 2015",x="Economy (GDP per Capita) 2015",data = happy_2015)
plt.suptitle("Happiness score and Economy 2015", fontsize=15)
# Out:
# Text(0.5, 0.98, 'Happiness score and Economy 2015')

# %%
sns.lmplot(y="Happiness Score 2016",x="Economy (GDP per Capita) 2016",data = happy_2016)
plt.suptitle("Happiness score and Economy 2016", fontsize=15)
# Out:
# Text(0.5, 0.98, 'Happiness score and Economy 2016')

# %%
happy_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 155 entries, 0 to 154
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        155 non-null    object
#  1   Happiness.Rank                 155 non-null    int64
#  2   Happiness.Score                155 non-null    float64
#  3   Whisker.high                   155 non-null    float64
#  4   Whisker.low                    155 non-null    float64
#  5   Economy..GDP.per.Capita.       155 non-null    float64
#  6   Family                         155 non-null    float64
#  7   Health..Life.Expectancy.       155 non-null    float64
#  8   Freedom                        155 non-null    float64
#  9   Generosity                     155 non-null    float64
#  10  Trust..Government.Corruption.  155 non-null    float64
#  11  Dystopia.Residual              155 non-null    float64
# ...

# %%
sns.lmplot(y="Happiness Score 2017",x="Economy GDP per Capita 2017",data = happy_2017)

# %%
sns.catplot(y="Happiness Score 2015", x="Region", data=happy_2015, kind ="bar")
plt.xticks(rotation=90)
plt.show()

# %%
sns.catplot(y="Happiness Score 2016", x="Region", data=happy_2016, kind ="bar")
plt.xticks(rotation=90)
plt.show()

# %%
happy_2015_score = happy_2015["Happiness Score 2015"]
ax = sns.distplot(happy_2015_score)
# Out:
# /home/rebecca/.local/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
ax = sns.violinplot(happy_2015_score)
# Out:
# /home/rebecca/.local/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
happy_2016_score = happy_2016["Happiness Score 2016"]
ax = sns.distplot(happy_2016_score)
# Out:
# /home/rebecca/.local/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
ax = sns.violinplot(happy_2016_score)
# Out:
# /home/rebecca/.local/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
happy_2017_score = happy_2017["Happiness Score 2017"]
ax = sns.distplot(happy_2017_score)
# Out:
# /home/rebecca/.local/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
ax = sns.violinplot(happy_2017_score)
# Out:
# /home/rebecca/.local/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
happy_2018_score = happy_2018["Score 2018"]
ax = sns.distplot(happy_2018_score)
# Out:
# /home/rebecca/.local/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
ax = sns.violinplot(happy_2018_score)
# Out:
# /home/rebecca/.local/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
happy_2019_score = happy_2019["Score 2019"]
ax = sns.distplot(happy_2019_score)
# Out:
# /home/rebecca/.local/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
ax = sns.violinplot(happy_2019_score)
# Out:
# /home/rebecca/.local/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
region_colors = {'Middle East and Northern Africa':'red',
                 'Latin America and Caribbean':'green',
                 'Eastern Asia':'aqua',
                 'Sub-Saharan Africa':'blue',
                 'Southeastern Asia':'grey',
                 'Western Europe':'pink',
                 'North America':'yellow',
                 'Australia and New Zealand':'orange',
                 'Central and Eastern Europe':'purple',
                 'Southern Asia':'olive'};

type(region_colors)
# Out:
# dict

# %%
colors = []
for i in happy_2015['Region']:
    
    colors.append(region_colors[i])

# %%
plt.clf()
plt.figure(figsize=(20,10))
plt.scatter(happy_2015['Economy (GDP per Capita) 2015'], happy_2015['Health (Life Expectancy) 2015'], s=(happy_2015['Happiness Score 2015']**4), alpha=0.5, c=colors)
plt.grid(True)

plt.xlabel("Economy")
plt.ylabel("Health")

plt.suptitle("Health Economy graph with sizes as Happiness score and colors as Region", fontsize=18)

plt.show()

# %%
colors = []
for i in happy_2016['Region']:
    
    colors.append(region_colors[i])

# %%
plt.clf()
plt.figure(figsize=(20,10))
plt.scatter(happy_2016['Economy (GDP per Capita) 2016'], happy_2016['Health (Life Expectancy) 2016'], s=(happy_2016['Happiness Score 2016']**4), alpha=0.5, c=colors)
plt.grid(True)

plt.xlabel("Economy")
plt.ylabel("Health")

plt.suptitle("Health Economy graph with sizes as Happiness score and colors as Region", fontsize=18)

plt.show()

# %%
merge = pd.merge(happy_2015[['Country','Happiness Score 2015','Happiness Rank 2015']], happy_2016[['Country','Happiness Score 2016','Happiness Rank 2016']], on='Country')
merge.head(10)
# Out:
#        Country  Happiness Score 2015  Happiness Rank 2015  \
# 0  Switzerland                 7.587                    1
# 1      Iceland                 7.561                    2
# 2      Denmark                 7.527                    3
# 3       Norway                 7.522                    4
# 4       Canada                 7.427                    5
# 5      Finland                 7.406                    6
# 6  Netherlands                 7.378                    7
# 7       Sweden                 7.364                    8
# 8  New Zealand                 7.286                    9
# 9    Australia                 7.284                   10
#
#    Happiness Score 2016  Happiness Rank 2016
# 0                 7.509                    2
# 1                 7.501                    3
# 2                 7.526                    1
# 3                 7.498                    4
# 4                 7.404                    6
# 5                 7.413                    5
# ...

# %%
merge = pd.merge(merge, happy_2017[['Country','Happiness Score 2017','Happiness Rank 2017']], on='Country')
merge.head(10)
# Out:
#        Country  Happiness Score 2015  Happiness Rank 2015  \
# 0  Switzerland                 7.587                    1
# 1      Iceland                 7.561                    2
# 2      Denmark                 7.527                    3
# 3       Norway                 7.522                    4
# 4       Canada                 7.427                    5
# 5      Finland                 7.406                    6
# 6  Netherlands                 7.378                    7
# 7       Sweden                 7.364                    8
# 8  New Zealand                 7.286                    9
# 9    Australia                 7.284                   10
#
#    Happiness Score 2016  Happiness Rank 2016  Happiness Score 2017  \
# 0                 7.509                    2                 7.494
# 1                 7.501                    3                 7.504
# 2                 7.526                    1                 7.522
# ...
